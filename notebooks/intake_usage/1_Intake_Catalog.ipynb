# %% [markdown]
# # Demonstrate use of the [Intake](https://intake.readthedocs.io/en/latest/index.html) catalog prepared for the AODN
#
# Not all the data available on the AODN S3 bucket has been indexed to allow 'cloud performant' access

# %% [markdown]
# ## Step 0: Import the library of code

# %%
import sys
sys.path.append('/home/jovyan/intake-aodn')
import intake_aodn
import intake
from  intake_aodn.easicache import set_easi
intake_aodn.cat = set_easi()
# Out:
# /home/jovyan/intake-aodn/intake_aodn/catalogs/aodn_refs.zip aodn_refs.zip s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au/aodn_refs.zip
# /home/jovyan/intake-aodn/intake_aodn/catalogs/main.yaml main.yaml s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au/main.yaml
# /home/jovyan/intake-aodn/intake_aodn/catalogs/aodn.yaml aodn.yaml s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au/aodn.yaml
# /home/jovyan/intake-aodn/intake_aodn/catalogs/nci.yaml nci.yaml s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au/nci.yaml

# %% [markdown]
# ## Step 1: Open and display the catalog

# %%
# Helper function to display the entries in an intake catalog
def display_entry(entry):
    import pandas as pd 
    print(f'NAME: {entry.name}')
    print(f'DESCRIPTION: {entry.description}')
    print(f'TYPE: {entry.container}')
    print(f'METADATA: ')
    for k,v in entry.metadata.items():
       print(f'    {k} : {v}') 
    print('USER PARAMETERS:')
    user_params = pd.DataFrame(entry.describe()['user_parameters'])
    display(user_params)

# %% [markdown]
# The top level catalog just contains entries for other catalogs

# %%
cat = intake_aodn.cat

for entry in cat:
    display_entry(cat[entry])
# Out:
# NAME: aodn_s3
# DESCRIPTION: AODN datasets indexed and available on AWS S3
# TYPE: catalog
# METADATA:
#     version : 1
# USER PARAMETERS:
# Empty DataFrame
# Columns: []
# Index: []
# NAME: nci
# DESCRIPTION: Datasets available on NCI Thredds Server
# TYPE: catalog
# METADATA:
#     version : 1
# USER PARAMETERS:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# We can access the entries of the catalog using '.' (dot) notation and loop through those. The

# %%
for entry in cat.aodn_s3:
    display_entry(cat.aodn_s3[entry])
# Out:
# NAME: SST_L3S_1d_ngt
# DESCRIPTION: IMOS - SRS - SST - L3S - Single Sensor - 1 day - night time - Australia
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/aaad092c-c3af-42e6-87e0-bdaef945f522
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# /tmp/ipykernel_72/3829521207.py:11: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   user_params = pd.DataFrame(entry.describe()['user_parameters'])
#       name                                        description      type  \
# 0  startdt  Start date of request (defaults to one month ago)  datetime
# 1    enddt            End date of request (defaults to today)  datetime
# 2     geom  Geometry in Well Known Text format to subset q...       str
#
#      default
# 0 1970-01-01
# 1 1970-01-01
# 2        NaT
# NAME: SSTAARS_Daily_Climatology
# DESCRIPTION: SST Atlas of Australian Regional Seas (SSTAARS) - Daily climatology fit
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/79c8eea2-4e86-4553-8237-4728e27abe10
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# Empty DataFrame
# Columns: []
# Index: []
# NAME: SSTAARS_Monthly_Climatology
# DESCRIPTION: SST Atlas of Australian Regional Seas (SSTAARS) - Monthly climatology fit
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/79c8eea2-4e86-4553-8237-4728e27abe10
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# Empty DataFrame
# Columns: []
# Index: []
# NAME: MODIS_1d_chl_oc3
# DESCRIPTION: IMOS - SRS - MODIS - 01 day - Chlorophyll-a concentration (OC3 model)
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/d7a14921-8f3f-4522-9a54-e7d1df969c8a
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# /tmp/ipykernel_72/3829521207.py:11: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   user_params = pd.DataFrame(entry.describe()['user_parameters'])
#       name                                        description      type  \
# 0  startdt                              Start date of request  datetime
# 1    enddt                                End date of request  datetime
# 2     geom  Geometry in Well Known Text format to subset q...       str
#
#      default
# 0 1970-01-01
# 1 1970-01-01
# 2        NaT
# NAME: MODIS_1d_chl_gsm
# DESCRIPTION: IMOS - SRS - MODIS - 01 day - Chlorophyll-a concentration (GSM model)
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/24055e3a-94e5-40bb-b97f-7519f0482d6a
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# /tmp/ipykernel_72/3829521207.py:11: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   user_params = pd.DataFrame(entry.describe()['user_parameters'])
#       name                                        description      type  \
# 0  startdt                              Start date of request  datetime
# 1    enddt                                End date of request  datetime
# 2     geom  Geometry in Well Known Text format to subset q...       str
#
#      default
# 0 1970-01-01
# 1 1970-01-01
# 2        NaT
# NAME: MODIS_1d_K_490
# DESCRIPTION: IMOS - SRS - MODIS - 01 day - Light Attenuation Coefficient at 490 nm
# TYPE: xarray
# METADATA:
#     permalink : https://catalogue-imos.aodn.org.au/geonetwork/srv/eng/catalog.search#/metadata/24055e3a-94e5-40bb-b97f-7519f0482d6a
#     catalog_dir : s3://easihub-csiro-user-scratch/AROAWO7MSC2TWB77JYRIM:csiro-csiro-aad_mor582@csiro.au
# USER PARAMETERS:
# /tmp/ipykernel_72/3829521207.py:11: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   user_params = pd.DataFrame(entry.describe()['user_parameters'])
#       name                                        description      type  \
# 0  startdt                              Start date of request  datetime
# 1    enddt                                End date of request  datetime
# 2     geom  Geometry in Well Known Text format to subset q...       str
#
#      default
# 0 1970-01-01
# 1 1970-01-01
# 2        NaT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       1 for entry in cat.aodn_s3:
# ----> 2     display_entry(cat.aodn_s3[entry])
#
# File /env/lib/python3.8/site-packages/intake/catalog/base.py:436, in Catalog.__getitem__(self, key)
#     427 """Return a catalog entry by name.
#     428
#     429 Can also use attribute syntax, like ``cat.entry_name``, or
#    (...)
#     432 cat['name1', 'name2']
#     433 """
#     434 if not isinstance(key, list) and key in self:
#     435     # triggers reload_on_change
# --> 436     s = self._get_entry(key)
#     437     if s.container == 'catalog':
#     438         s.name = key
#
# File /env/lib/python3.8/site-packages/intake/catalog/utils.py:45, in reload_on_change.<locals>.wrapper(self, *args, **kwargs)
#      42 @functools.wraps(f)
#      43 def wrapper(self, *args, **kwargs):
#      44     self.reload()
# ---> 45     return f(self, *args, **kwargs)
#
# File /env/lib/python3.8/site-packages/intake/catalog/base.py:323, in Catalog._get_entry(self, name)
#     321 ups = [up for name, up in self.user_parameters.items() if name not in up_names]
#     322 entry._user_parameters = ups + (entry._user_parameters or [])
# --> 323 return entry()
#
# File /env/lib/python3.8/site-packages/intake/catalog/entry.py:77, in CatalogEntry.__call__(self, persist, **kwargs)
#      75     raise ValueError('Persist value (%s) not understood' % persist)
#      76 persist = persist or self._pmode
# ---> 77 s = self.get(**kwargs)
#      78 if persist != 'never' and isinstance(s, PersistMixin) and s.has_been_persisted:
#      79     from ..container.persist import store
#
# File /env/lib/python3.8/site-packages/intake/catalog/local.py:290, in LocalCatalogEntry.get(self, **user_parameters)
#     287     return self._default_source
#     289 plugin, open_args = self._create_open_args(user_parameters)
# --> 290 data_source = plugin(**open_args)
#     291 data_source.catalog_object = self._catalog
#     292 data_source.name = self.name
#
# File /env/lib/python3.8/site-packages/intake_xarray/netcdf.py:63, in NetCDFSource.__init__(self, urlpath, chunks, combine, concat_dim, xarray_kwargs, metadata, path_as_pattern, storage_options, **kwargs)
#      61 else:
#      62     self._can_be_local = fsspec.utils.can_be_local(self.urlpath)
# ---> 63 super(NetCDFSource, self).__init__(metadata=metadata, **kwargs)
#
# TypeError: __init__() got an unexpected keyword argument 'csv_kwargs'

# %% [markdown]
# ## Step 2: Open the SST catalog entry with some 'user supplied' parameters

# %%
import fiona # A library for lots of geospatial analysis
import geopandas as gpd # A library for opening shapefiles (and the like) and displaying their attribues and geometry
import matplotlib.pyplot as plt # A general purpose plotting library
import cartopy.crs as ccrs # Library for plotting maps in python
import cartopy.feature as cf # Library for plotting maps in python

gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw' #adds support for reading KML to geopandas
gdf = gpd.read_file('SharkBay.kml', driver='KML')
gdf
# Out:
#        Name Description                                           geometry
# 0  SharkBay              POLYGON Z ((113.61460 -24.56049 0.00000, 113.4...

# %% [markdown]
# Make a quick plot of the polygon

# %%
ax = plt.axes(projection = ccrs.PlateCarree())
gdf.plot(ax=ax)
ax.add_feature(cf.COASTLINE)

# %% [markdown]
# ## Step 3: Read the data for the entry into memory for use
#
# This subsets and composes the data across all the 365 files into a single dataset. The files are shown here: http://thredds.aodn.org.au/thredds/catalog/IMOS/SRS/SST/ghrsst/L3S-1d/ngt/2011/catalog.html.
#
# This takes a couple of minutes, but at the moment we are only using 1 cpu to loop through - later we will show how to speed it up by making use of more CPUs

# %% [markdown]
# Get an entry with our chosen input user parameters, in this instance 2011

# %%
# %%time
entry=intake_aodn.cat.aodn_s3.SST_L3S_1d_ngt(startdt='2011-01-01',
                                             enddt='2012-01-01',
                                             geom=str(gdf.geometry[0])) # Geometry string in WKT

ds = entry.read()
ds
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:5, in <module>
#
# File ~/intake-aodn/intake_aodn/drivers.py:86, in RefZarrStackSource.read(self)
#      84 """Return xarray object where variables are dask arrays"""
#      85 self._load_data = True
# ---> 86 self._load_metadata()
#      87 return self._ds
#
# File /env/lib/python3.8/site-packages/intake/source/base.py:236, in DataSourceBase._load_metadata(self)
#     234 """load metadata only if needed"""
#     235 if self._schema is None:
# --> 236     self._schema = self._get_schema()
#     237     self.dtype = self._schema.dtype
#     238     self.shape = self._schema.shape
#
# File /env/lib/python3.8/site-packages/intake_xarray/base.py:18, in DataSourceMixin._get_schema(self)
#      15 self.urlpath = self._get_cache(self.urlpath)[0]
#      17 if self._ds is None:
# ---> 18     self._open_dataset()
#      20     metadata = {
#      21         'dims': dict(self._ds.dims),
#      22         'data_vars': {k: list(self._ds[k].coords)
#      23                       for k in self._ds.data_vars.keys()},
#      24         'coords': tuple(self._ds.coords.keys()),
#      25     }
#      26     if getattr(self, 'on_server', False):
#
# File ~/intake-aodn/intake_aodn/drivers.py:193, in RefZarrStackSource._open_dataset(self)
#     191         f_url = f'simplecache::zip://{f}::{urlparts[-1]}' #f'{fs.protocol}://{f}::' + '::'.join(urlparts[1:])
#     192         futures.append(d_open_dataset(f_url,**open_kwargs))
# --> 193 dsets = compute(futures)[0]
#     195 for i,ds in enumerate(dsets):
#     196     if ds is None:
#
# File /env/lib/python3.8/site-packages/dask/base.py:575, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     572     keys.append(x.__dask_keys__())
#     573     postcomputes.append(x.__dask_postcompute__())
# --> 575 results = schedule(dsk, keys, **kwargs)
#     576 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /env/lib/python3.8/site-packages/dask/threaded.py:81, in get(dsk, result, cache, num_workers, pool, **kwargs)
#      78     elif isinstance(pool, multiprocessing.pool.Pool):
#      79         pool = MultiprocessingPoolExecutor(pool)
# ---> 81 results = get_async(
#      82     pool.submit,
#      83     pool._max_workers,
#      84     dsk,
#      85     result,
#      86     cache=cache,
#      87     get_id=_thread_get_id,
#      88     pack_exception=pack_exception,
#      89     **kwargs,
#      90 )
#      92 # Cleanup pools associated to dead threads
#      93 with pools_lock:
#
# File /env/lib/python3.8/site-packages/dask/local.py:497, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     495 while state["waiting"] or state["ready"] or state["running"]:
#     496     fire_tasks(chunksize)
# --> 497     for key, res_info, failed in queue_get(queue).result():
#     498         if failed:
#     499             exc, tb = loads(res_info)
#
# File /env/lib/python3.8/site-packages/dask/local.py:134, in queue_get(q)
#     133 def queue_get(q):
# --> 134     return q.get()
#
# File /usr/lib/python3.8/queue.py:170, in Queue.get(self, block, timeout)
#     168 elif timeout is None:
#     169     while not self._qsize():
# --> 170         self.not_empty.wait()
#     171 elif timeout < 0:
#     172     raise ValueError("'timeout' must be a non-negative number")
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step 4: Save the data to netcdf

# %%
# Need to drop the "NAME" and "_Netcdf4Dimid" which are reserved when writing back out to netCDF
# Unclear why they are in the dataset
for v in ds.variables:
    for bad_attr in ['_Netcdf4Dimid','NAME']:
        if bad_attr in ds[v].attrs.keys():
            del ds[v].attrs[bad_attr]
            
ds.to_netcdf('SharkBay_SST_2011.nc')

# %% [markdown]
# Open the saved data to convince ourselves it has saved correctly

# %%
import xarray as xr
ds = xr.open_dataset('SharkBay_SST_2011.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 365, latitude: 114, longitude: 84)
# Coordinates:
#   * latitude                 (latitude) float32 -24.49 -24.51 ... -26.73 -26.75
#   * longitude                (longitude) float32 112.8 112.8 ... 114.5 114.5
#   * time                     (time) datetime64[ns] 2011-01-01T15:20:00 ... 20...
# Data variables:
#     dt_analysis              (time, latitude, longitude) float32 ...
#     l2p_flags                (time, latitude, longitude) float32 ...
#     quality_level            (time, latitude, longitude) float32 ...
#     satellite_zenith_angle   (time, latitude, longitude) float32 ...
#     sea_surface_temperature  (time, latitude, longitude) float32 ...
#     sses_bias                (time, latitude, longitude) float32 ...
#     sses_count               (time, latitude, longitude) float32 ...
#     sses_standard_deviation  (time, latitude, longitude) float32 ...
#     sst_dtime                (time, latitude, longitude) float64 ...
# Attributes: (12/50)
#     Conventions:                      CF-1.6
#     Metadata_Conventions:             Unidata Dataset Discovery v1.0
#     Metadata_Link:                    TBA
#     acknowledgment:                   Any use of these data requires the foll...
#     cdm_data_type:                    grid
#     comment:                          HRPT AVHRR experimental L3 retrieval pr...
#     ...                               ...
#     summary:                          Skin SST retrievals produced from stitc...
#     time_coverage_end:                20110101T205806Z
#     time_coverage_start:              20110101T132645Z
#     title:                            IMOS L3S Nighttime gridded multiple-sen...
#     uuid:                             5bc0e9b4-a261-42d2-bd31-0cccd1878500
#     westernmost_longitude:            70.01000213623047

# %% [markdown]
# ## Step 4: Open the datafiles in S3 and but dont read any data, just the 'metadata'
#
# This is useful if the data is large and wont fit into memory - note the arrays no longer have values in them, but rather are [DASK](https://docs.dask.org/en/stable/index.html) arrays to allow for parallel computing.
#
# This returns quicker, but the data has to be loaded later during the calculation.

# %%
# %%time
entry=intake_aodn.cat.aodn_s3.SST_L3S_1d_ngt(startdt='2011-01-01',
                                             enddt='2012-01-01',
                                             geom=str(gdf.geometry[0])) 
ds = entry.to_dask()
ds
# Out:
# CPU times: user 745 ms, sys: 45.3 ms, total: 790 ms
# Wall time: 1.7 s
# <xarray.Dataset>
# Dimensions:                  (time: 365, latitude: 114, longitude: 84)
# Coordinates:
#   * latitude                 (latitude) float32 -24.49 -24.51 ... -26.73 -26.75
#   * longitude                (longitude) float32 112.8 112.8 ... 114.5 114.5
#   * time                     (time) datetime64[ns] 2011-01-01T15:20:00 ... 20...
# Data variables:
#     dt_analysis              (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     l2p_flags                (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     quality_level            (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     satellite_zenith_angle   (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     sea_surface_temperature  (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     sses_bias                (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     sses_count               (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     sses_standard_deviation  (time, latitude, longitude) float32 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
#     sst_dtime                (time, latitude, longitude) float64 dask.array<chunksize=(365, 114, 84), meta=np.ndarray>
# Attributes: (12/50)
#     Conventions:                      CF-1.6
#     Metadata_Conventions:             Unidata Dataset Discovery v1.0
#     Metadata_Link:                    TBA
#     acknowledgment:                   Any use of these data requires the foll...
#     cdm_data_type:                    grid
#     comment:                          HRPT AVHRR experimental L3 retrieval pr...
#     ...                               ...
#     summary:                          Skin SST retrievals produced from stitc...
#     time_coverage_end:                20110101T205806Z
#     time_coverage_start:              20110101T132645Z
#     title:                            IMOS L3S Nighttime gridded multiple-sen...
#     uuid:                             5bc0e9b4-a261-42d2-bd31-0cccd1878500
#     westernmost_longitude:            70.01000213623047
